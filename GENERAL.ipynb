# %%
# How to formulate?
def Input():
    return 0

def Formulation():
    def Mathematical(): #  Written IRL
        return 0
    def Classical():
        return 0
    def QUBO():
        return 0

def SolverChooser():
    def SolverClassical():
        return 0
    def SolverHybrid():
        return 0
    def SolverQuantum():
        return 0
    
def Output(results):
    return 0
